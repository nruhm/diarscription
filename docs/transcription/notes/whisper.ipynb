# %% [markdown]
# You can use the whisper module to take an audio file and transcribe it.
# Python version used in this example: Python 3.12.11

# %%
import whisper
# Out:
# Running cells with 'Python 3.12.11' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/nathanjruhmann/AppData/Roaming/uv/python/cpython-3.12.11-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'
